# %%
import numpy as np
import pandas as pd
import time

# %%
# input data
train =  pd.read_csv('input/train.csv')
test =  pd.read_csv('input/test.csv')

# %%
print(train["Semana"].unique())
print(test["Semana"].unique())
# Out:
# [3 4 5 6 7 8 9]
# [11 10]

# %%
# change colimn names to english
train.columns = ['WeekNum', 'DepotId', 'ChannelId', 'RouteId', 'ClientId',\
                    'ProductId', 'SalesUnitsWeek', 'SalesPesosWeek',\
                    'ReturnsUnitsWeek', 'ReturnsPesosWeek', 'AdjDemand']
test.columns = ['id', 'WeekNum', 'DepotId', 'ChannelId', 'RouteId', 'ClientId',\
                    'ProductId']

# %%
list(train.columns.values)
# Out:
# ['WeekNum',
#  'DepotId',
#  'ChannelId',
#  'RouteId',
#  'ClientId',
#  'ProductId',
#  'SalesUnitsWeek',
#  'SalesPesosWeek',
#  'ReturnsUnitsWeek',
#  'ReturnsPesosWeek',
#  'AdjDemand']

# %%
grouped = train.groupby(['ClientId', 'ProductId'], as_index=False)

# %%
med = grouped.median()

# %%
res = med[['ClientId', 'ProductId', 'AdjDemand']]

# %%
merged = pd.merge(test, res, how="left", on=['ClientId', 'ProductId'])

# %%
merged['AdjDemand'].fillna(merged['AdjDemand'].median(), inplace=True)

# %%
merged[['id', 'AdjDemand']]
# Out:
#               id  AdjDemand
# 0              0        4.0
# 1              1        4.0
# 2              2        2.0
# 3              3        4.0
# 4              4        4.0
# 5              5        3.0
# 6              6        1.0
# 7              7        4.0
# 8              8        6.0
# 9              9        5.0
# 10            10        8.0
# 11            11        2.0
# 12            12        6.5
# 13            13        7.0
# 14            14        2.0
# 15            15        4.0
# 16            16        4.0
# 17            17        2.0
# 18            18        1.5
# 19            19        4.0
# 20            20        6.0
# 21            21       10.0
# 22            22       11.0
# 23            23        2.0
# 24            24        1.0
# 25            25        7.0
# 26            26        4.0
# 27            27        4.0
# 28            28        1.0
# 29            29        1.0
# ...          ...        ...
# 6999221  6999221        4.0
# ...

# %%
result = merged[['id', 'AdjDemand']]
result.columns = ['id','Demanda_uni_equil']
filename = 'output/submission_%s.csv.gz' % time.strftime("%Y%m%d%H%M")
result.to_csv(filename, index=False, compression='gzip')
print(filename + " written")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-16463b86aaf5> in <module>()
#       2 result.columns = ['id','Demanda_uni_equil']
#       3 filename = 'output/submission_%s.csv.gz' % time.strftime("%Y%m%d%H%M")
# ----> 4 result.to_csv(filename, index=False, compression='gzip')
#
# /home/ozgun/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal, **kwds)
#    1341                                      doublequote=doublequote,
#    1342                                      escapechar=escapechar, decimal=decimal)
# -> 1343         formatter.save()
#    1344
#    1345         if path_or_buf is None:
#
# ...
